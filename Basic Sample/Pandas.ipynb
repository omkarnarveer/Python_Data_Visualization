# %%
#Importing pandas Library
import pandas as pd

# %% [markdown]
# # Write a Program to read a dataset and print its first and last 5 entities

# %%
#reading dataset
df=pd.read_excel("Name_List For_T.E. Result 5th SEM(2019 PAT.)(COMPUTER)_Exam.xlsx")

# %%
#view of first 5 record
df.head()
# Out:
#    Roll No             Student Name  DBMS   TOC  SPOS   CNS  ESIOT  \
# 0      1.0        ATTAR SUMERA ARIF  48.0  50.0  50.0  50.0   45.0
# 1      2.0        AUTI DIVYA SANJAY  50.0  50.0  50.0  50.0   40.0
# 2      3.0       BADHE MAYUR SURESH  50.0  50.0  50.0  50.0   39.0
# 3      4.0     BANGAR AKSHADA SUNIL  49.0  45.0  50.0  50.0   42.0
# 4      5.0  BANGAR SHRADDHA NAVNATH  50.0  50.0  50.0  50.0   50.0
#
#    Honours(Optional)  Total  Total Out of 70
# 0                NaN  243.0            340.2
# 1                NaN  240.0            336.0
# 2                NaN  239.0            334.6
# 3                NaN  236.0            330.4
# 4                NaN  250.0            350.0

# %%
#view of last 5 record
df.tail()
# Out:
#     Roll No            Student Name  DBMS   TOC  SPOS   CNS  ESIOT  \
# 75     76.0       UKIRDE ROHAN ANIL  50.0  45.0  50.0  50.0   49.0
# 76     77.0         WAGH VIKAS RAJU  50.0  50.0  50.0  48.0   47.0
# 77     78.0    WAVHAL RUTURAJ SAGAR  50.0  50.0  50.0  50.0   37.0
# 78     79.0    YENDHE KIRTI YUVARAJ  50.0  46.0  50.0  50.0   38.0
# 79      NaN  GAYKAWAD AKSHAY SURESH   NaN   NaN   NaN   NaN    NaN
#
#     Honours(Optional)  Total  Total Out of 70
# 75                NaN  244.0            341.6
# 76                NaN  245.0            343.0
# 77                NaN  237.0            331.8
# 78                NaN  234.0            327.6
# 79                NaN    0.0              0.0

# %% [markdown]
# # Write a progam to print random 10 entites of a dataset and find its size and description

# %%
#shows random 10 records
df.sample(10)
# Out:
#     Roll No                  Student Name  DBMS   TOC  SPOS   CNS  ESIOT  \
# 35     36.0           JAWARE KIRAN SANJAY  47.0  47.0  50.0  50.0   45.0
# 34     35.0            JADHAV ROSHAN ARUN  43.0  43.0  50.0  50.0   45.0
# 72     73.0         TEMKAR SIDDHI SOMNATH  40.0  44.0  50.0  50.0   39.0
# 31     32.0       HUMBE RUPESH RAMCHANDRA  44.0  50.0  50.0  50.0   47.0
# 41     42.0       KEDARI VAISHNAVI KAILAS  47.0  50.0  50.0  49.0   43.0
# 67     68.0           SHINDE TRUPTI DILIP  46.0  49.0  50.0  50.0   42.0
# 18     19.0  DATKHILE PRATHAMESH JALINDAR  50.0  50.0  50.0  50.0   48.0
# 17     18.0       DATKHILE JANAVI JAGDISH  50.0  46.0  50.0  50.0   46.0
# 11     12.0           CHASKAR SHWETA BALU  50.0  50.0  50.0  50.0   45.0
# 49     50.0              MOMIN SANA CHAND  42.0  43.0  50.0  50.0   42.0
#
#     Honours(Optional)  Total  Total Out of 70
# 35                NaN  239.0            334.6
# 34                NaN  231.0            323.4
# ...

# %%
#shows size of dataset
df.shape
# Out:
# (80, 10)

# %%
#shows description of dataset
df.describe()
# Out:
#          Roll No       DBMS        TOC       SPOS        CNS      ESIOT  \
# count  79.000000  78.000000  78.000000  78.000000  78.000000  78.000000
# mean   40.000000  47.064103  47.269231  49.679487  49.474359  42.833333
# std    22.949219   3.804781   3.518681   1.400312   1.703506   4.868176
# min     1.000000  29.000000  34.000000  40.000000  42.000000  29.000000
# 25%    20.500000  46.000000  45.000000  50.000000  50.000000  39.250000
# 50%    40.000000  48.000000  49.000000  50.000000  50.000000  43.000000
# 75%    59.500000  50.000000  50.000000  50.000000  50.000000  46.000000
# max    79.000000  50.000000  50.000000  50.000000  50.000000  50.000000
#
#        Honours(Optional)       Total  Total Out of 70
# count                0.0   79.000000        79.000000
# mean                 NaN  233.329114       326.660759
# std                  NaN   28.753025        40.254235
# min                  NaN    0.000000         0.000000
# ...

# %% [markdown]
# # write a program to find missing values in dataset

# %%
#shows null value in dataset as true
df.isnull()
# Out:
#     Roll No  Student Name   DBMS    TOC   SPOS    CNS  ESIOT  \
# 0     False         False  False  False  False  False  False
# 1     False         False  False  False  False  False  False
# 2     False         False  False  False  False  False  False
# 3     False         False  False  False  False  False  False
# 4     False         False  False  False  False  False  False
# ..      ...           ...    ...    ...    ...    ...    ...
# 75    False         False  False  False  False  False  False
# 76    False         False  False  False  False  False  False
# 77    False         False  False  False  False  False  False
# 78    False         False  False  False  False  False  False
# 79     True         False   True   True   True   True   True
#
#     Honours(Optional)  Total  Total Out of 70
# 0                True  False            False
# 1                True  False            False
# 2                True  False            False
# ...

# %% [markdown]
# # Write a program to remove null valus coloumn vise

# %%
#to drop null value coloumn wise
to_drop=['Honours(Optional)']
df.drop(to_drop, inplace=True, axis=1)

# %%
#to check null values
df.isnull()
# Out:
#     Roll No  Student Name   DBMS    TOC   SPOS    CNS  ESIOT  Total  \
# 0     False         False  False  False  False  False  False  False
# 1     False         False  False  False  False  False  False  False
# 2     False         False  False  False  False  False  False  False
# 3     False         False  False  False  False  False  False  False
# 4     False         False  False  False  False  False  False  False
# ..      ...           ...    ...    ...    ...    ...    ...    ...
# 74    False         False  False  False  False  False  False  False
# 75    False         False  False  False  False  False  False  False
# 76    False         False  False  False  False  False  False  False
# 77    False         False  False  False  False  False  False  False
# 78    False         False  False  False  False  False  False  False
#
#     Total Out of 70
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# ...

# %%
print(df.to_string())
# Out:
#     Roll No                    Student Name  DBMS   TOC  SPOS   CNS  ESIOT  Total  Total Out of 70
# 0       1.0               ATTAR SUMERA ARIF  48.0  50.0  50.0  50.0   45.0  243.0            340.2
# 1       2.0               AUTI DIVYA SANJAY  50.0  50.0  50.0  50.0   40.0  240.0            336.0
# 2       3.0              BADHE MAYUR SURESH  50.0  50.0  50.0  50.0   39.0  239.0            334.6
# 3       4.0            BANGAR AKSHADA SUNIL  49.0  45.0  50.0  50.0   42.0  236.0            330.4
# 4       5.0         BANGAR SHRADDHA NAVNATH  50.0  50.0  50.0  50.0   50.0  250.0            350.0
# 5       6.0             BANKAR PRASAD KIRAN  50.0  50.0  50.0  50.0   39.0  239.0            334.6
# 7       8.0            BHOR RUTIKA RAJENDRA  44.0  50.0  50.0  50.0   39.0  233.0            326.2
# 8       9.0               BHOR SEJAL SANJAY  48.0  50.0  50.0  50.0   41.0  239.0            334.6
# ...

# %% [markdown]
# # Write a program to remove null values Row Wise

# %%
#to drop all null values row Wise
df.dropna(inplace = True)
print(df.to_string())
# Out:
#     Roll No                    Student Name  DBMS   TOC  SPOS   CNS  ESIOT  Total  Total Out of 70
# 0       1.0               ATTAR SUMERA ARIF  48.0  50.0  50.0  50.0   45.0  243.0            340.2
# 1       2.0               AUTI DIVYA SANJAY  50.0  50.0  50.0  50.0   40.0  240.0            336.0
# 2       3.0              BADHE MAYUR SURESH  50.0  50.0  50.0  50.0   39.0  239.0            334.6
# 3       4.0            BANGAR AKSHADA SUNIL  49.0  45.0  50.0  50.0   42.0  236.0            330.4
# 4       5.0         BANGAR SHRADDHA NAVNATH  50.0  50.0  50.0  50.0   50.0  250.0            350.0
# 5       6.0             BANKAR PRASAD KIRAN  50.0  50.0  50.0  50.0   39.0  239.0            334.6
# 7       8.0            BHOR RUTIKA RAJENDRA  44.0  50.0  50.0  50.0   39.0  233.0            326.2
# 8       9.0               BHOR SEJAL SANJAY  48.0  50.0  50.0  50.0   41.0  239.0            334.6
# ...
